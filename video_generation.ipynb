# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranZahra789/Kiran-Zahra/blob/main/video_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
# !pip install langchain_google_genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
 api_key =  GEMINI_API_KEY,
 model = 'gemini-2.0-flash-exp'

)

# %%
from google.colab import files

# Prompt the user to upload a video file
uploaded = files.upload()

# Retrieve the name of the uploaded file
for file_name in uploaded.keys():
    print(f"Uploaded file: {file_name}")
# Out:
#      <input type="file" id="files-f0ee7eef-17be-4f16-9f5f-2251d148fe50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0ee7eef-17be-4f16-9f5f-2251d148fe50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google import genai
from google.genai import Client

# %%
model: str = "gemini-2.0-flash-exp"
client: Client = genai.Client(
      api_key = GEMINI_API_KEY,
)

# %%
import time

def upload_video(video_file_name):
  video_file = client.files.upload(path="/content/Embrace the Dawn_ A Fresh Start-VEED.mp4")
  while video_file.state == "PROCESSING":
      print('Waiting for video to be processed.')
      time.sleep(10)
      video_file = client.files.get(name=video_file.name or "")

  if video_file.state == "FAILED":
    raise ValueError(video_file.state)
  print(f'Video processing complete: ' + (video_file.uri or ""))

  return video_file

pottery_video = upload_video('Pottery.mp4')
# Out:
# Waiting for video to be processed.
# Video processing complete: https://generativelanguage.googleapis.com/v1beta/files/7tsejwlhupr3

# %%
from IPython.display import display, Audio ,Markdown

# %%
def generate_video_captions(video):

    # Predefined model and client
    model = "gemini-2.0-flash-exp"  # Replace with your actual model name
    client: Client = genai.Client(
    api_key=GEMINI_API_KEY,
    )
    prompt = """For each scene in this video,
                generate captions that describe the scene, along with spoken text.
                Place each caption into an object with the timecode of the caption in the video.
             """

    # Generate content using the API
    response = client.models.generate_content(
        model=model,
        contents=[
            Content(
                role="user",
                parts=[
                    Part.from_uri(
                        file_uri=video.uri or "",
                        mime_type=video.mime_type or ""
                    ),
                ]
            ),
            prompt,
        ]
    )
     # Extract and format the response as Markdown
    scenes = response.text
    return Markdown(scenes)

# %%
generate_video_captions(pottery_video)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-f3cb826473ab> in <cell line: 1>()
# ----> 1 generate_video_captions(pottery_video)
#
# <ipython-input-32-bc6daa8c16db> in generate_video_captions(video)
#      15         model=model,
#      16         contents=[
# ---> 17             Content(
#      18                 role="user",
#      19                 parts=[
#
# NameError: name 'Content' is not defined
